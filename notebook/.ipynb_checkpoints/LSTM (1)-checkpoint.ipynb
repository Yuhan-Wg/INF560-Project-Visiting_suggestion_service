# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy
import tensorflow as tf
import sys
sys.path.append("..")
from src.prestep.datetime_extension import timedate_process

# %%
#read block data
df=pd.read_csv("../input/blocks.csv",header=0)
df = timedate_process(df)
#print(df.shape)
df.head()
# Out:
#    Level  latBlock  lngBlock  month  day  hour  ClientMacAddr  year  \
# 0      0         0        20      4    1    10              1  2018
# 1      0         0        20      4    2    16              1  2018
# 2      0         0        20      4    3    10              1  2018
# 3      0         0        20      4    3    16              1  2018
# 4      0         0        20      4    3    17              1  2018
#
#    dayofweek holiday     ...      Highest 120 Min Rainfall (mm)  \
# 0          6   False     ...                                8.6
# 1          0   False     ...                                1.6
# 2          1   False     ...                                0.0
# 3          1   False     ...                                0.0
# 4          1   False     ...                                0.0
#
#    Mean Temperature (∞C)  Maximum Temperature (∞C)  Minimum Temperature (∞C)  \
# 0                   27.7                      32.9                      25.6
# 1                   28.7                      32.8                      26.5
# 2                   28.9                      33.0                      26.8
# 3                   28.9                      33.0                      26.8
# 4                   28.9                      33.0                      26.8
#
#    Mean Wind Speed (km/h)  Max Wind Speed (km/h)  eventFest  eventArt  \
# 0                     7.2                   22.3      False     False
# 1                     8.3                   29.5      False     False
# 2                     7.2                   25.9      False     False
# 3                     7.2                   25.9      False     False
# 4                     7.2                   25.9      False     False
#
#    eventinACM eventinPSCS
# 0       False       False
# 1       False       False
# 2       False       False
# 3       False       False
# 4       False       False
#
# [5 rows x 23 columns]

# %%
common_features = ["latBlock","lngBlock","Level","year","month","day","hour","ClientMacAddr"]
features = [d for d in df.columns if d not in common_features]
features
# Out:
# ['dayofweek',
#  'holiday',
#  'Daily Rainfall Total (mm)',
#  'Highest 30 Min Rainfall (mm)',
#  'Highest 60 Min Rainfall (mm)',
#  'Highest 120 Min Rainfall (mm)',
#  'Mean Temperature (∞C)',
#  'Maximum Temperature (∞C)',
#  'Minimum Temperature (∞C)',
#  'Mean Wind Speed (km/h)',
#  'Max Wind Speed (km/h)',
#  'eventFest',
#  'eventArt',
#  'eventinACM',
#  'eventinPSCS']

# %%
df[features].head()
# Out:
#    year  dayofweek holiday  Daily Rainfall Total (mm)  \
# 0  2018          6   False                        8.8
# 1  2018          0   False                        1.6
# 2  2018          1   False                        0.0
# 3  2018          1   False                        0.0
# 4  2018          1   False                        0.0
#
#    Highest 30 Min Rainfall (mm)  Highest 60 Min Rainfall (mm)  \
# 0                           5.8                           7.8
# 1                           1.6                           1.6
# 2                           0.0                           0.0
# 3                           0.0                           0.0
# 4                           0.0                           0.0
#
#    Highest 120 Min Rainfall (mm)  Mean Temperature (∞C)  \
# 0                            8.6                   27.7
# 1                            1.6                   28.7
# 2                            0.0                   28.9
# 3                            0.0                   28.9
# 4                            0.0                   28.9
#
#    Maximum Temperature (∞C)  Minimum Temperature (∞C)  Mean Wind Speed (km/h)  \
# 0                      32.9                      25.6                     7.2
# 1                      32.8                      26.5                     8.3
# 2                      33.0                      26.8                     7.2
# 3                      33.0                      26.8                     7.2
# 4                      33.0                      26.8                     7.2
#
#    Max Wind Speed (km/h) eventFest eventArt eventinACM eventinPSCS
# 0                   22.3     False    False      False       False
# 1                   29.5     False    False      False       False
# 2                   25.9     False    False      False       False
# 3                   25.9     False    False      False       False
# 4                   25.9     False    False      False       False

# %%
def date_prepare(df,lat=0,lng=15,month=7,day=14,hour=16):
        #get the nearby blocks
    #print(df[(df.latBlock==lat) & (df.lngBlock==lng) & (df.month==month) &(df.day==day) &(df.hour==hour)])
    block=[]



    #first decribe the count of this block 
    if len(df[(df.latBlock==lat) & (df.lngBlock==lng) & (df.month==month) &(df.day==day) &(df.hour==hour)]['ClientMacAddr'])>0:
        block.append(int(df[(df.latBlock==lat) & (df.lngBlock==lng) & (df.month==month) &(df.day==day) &(df.hour==hour)]['ClientMacAddr']))
    else:
        block.append(0)
            



    #second decribe the average of upper left lower right block
    count_card=0
    sum_card=0
    upper=df[(df.latBlock==lat-1) & (df.lngBlock==lng) & (df.month==month) &(df.day==day) &(df.hour==hour)]['ClientMacAddr']
    if len(upper)>0:
        count_card=count_card+1
        sum_card=sum_card+int(upper)

    lower=df[(df.latBlock==lat+1) & (df.lngBlock==lng) & (df.month==month) &(df.day==day) &(df.hour==hour)]['ClientMacAddr']
    if len(lower)>0:
        count_card=count_card+1
        sum_card=sum_card+int(lower)

    left=df[(df.latBlock==lat) & (df.lngBlock==lng-1) & (df.month==month) &(df.day==day) &(df.hour==hour)]['ClientMacAddr']
    if len(left)>0:
        count_card=count_card+1
        sum_card=sum_card+int(left)

    right=df[(df.latBlock==lat) & (df.lngBlock==lng+1) & (df.month==month) &(df.day==day) &(df.hour==hour)]['ClientMacAddr']
    if len(right)>0:
        count_card=count_card+1
        sum_card=sum_card+int(right)

    if count_card>0:
        avg_card=sum_card/count_card
    else:
        avg_card=0
    #print(avg_card)
    block.append(avg_card)



    #third decrible intercardinal blocks
    count_intercard=0
    sum_intercard=0
    block_inter1=df[(df.latBlock==lat-1) & (df.lngBlock==lng-1) & (df.month==month) &(df.day==day) &(df.hour==hour)]['ClientMacAddr']
    if len(block_inter1)>0:
        count_intercard=count_intercard+1
        sum_intercard=sum_intercard+int(block_inter1)

    block_inter2=df[(df.latBlock==lat-1) & (df.lngBlock==lng+1) & (df.month==month) &(df.day==day) &(df.hour==hour)]['ClientMacAddr']
    if len(block_inter2)>0:
        count_intercard=count_intercard+1
        sum_intercard=sum_intercard+int(block_inter2)

    block_inter3=df[(df.latBlock==lat+1) & (df.lngBlock==lng-1) & (df.month==month) &(df.day==day) &(df.hour==hour)]['ClientMacAddr']
    if len(block_inter3)>0:
        count_intercard=count_intercard+1
        sum_intercard=sum_intercard+int(block_inter3)

    block_inter4=df[(df.latBlock==lat+1) & (df.lngBlock==lng+1) & (df.month==month) &(df.day==day) &(df.hour==hour)]['ClientMacAddr']
    if len(block_inter4)>0:
        count_intercard=count_intercard+1
        sum_intercard=sum_intercard+int(block_inter4)

    if count_intercard>0:
        avg_intercard=sum_intercard/count_intercard
    else:
        avg_intercard=0
    #print(avg_intercard)
    block.append(avg_intercard)
    block.append(df[features])
    return block

# %%
#print(date_prepare(df,0,15,7,14,16))
data_set=[]
for k in range(1,31):
    for i in range(0,23):
        data_set.append(date_prepare(df,0,15,5,k,i))
    #print(date_prepare(df,0,15,7,14,i))
#print(data_set)

# %%
data=data_set
#print(data_set)
#normalize data
normalize_data=(data-np.mean(data))/np.std(data)  
normalize_data=normalize_data[:,np.newaxis] 
k=[]
for i in normalize_data:
    a=[]
    for r in i[0]:
        b=[]
        b.append(r)
        a.append(b)
    k.append(a)
#print(k)
normalize_data=k

# %%
train_out=[]
for i in normalize_data:
    train_out.append(i[0])

normalize_data=k

train_in=normalize_data
#print(train_in)
#print(train_in)
#print('###########')
#print(train_out)

# %%
NUM_EXAMPLES=500
length_timeshift=len(train_in)
train_in=train_in[:length_timeshift-12]
train_out=train_out[12:]
test_input=train_in[NUM_EXAMPLES:]
test_output=train_out[NUM_EXAMPLES:]

train_input=train_in[:NUM_EXAMPLES]
train_output=train_out[:NUM_EXAMPLES]

#print(train_input)

#print('$$$$')

#print(train_output)

for i in range(0,10):
    print(train_input[i])
    print(train_output[i])

data = tf.placeholder(tf.float32, [None, len(features)+2,1])
target = tf.placeholder(tf.float32, [None, 1])

num_hidden = 24
# cell = tf.nn.rnn_cell.LSTMCell(num_hidden,state_is_tuple=True)
cell = tf.contrib.rnn.LSTMCell(num_hidden,state_is_tuple=True)

val, _ = tf.nn.dynamic_rnn(cell, data, dtype=tf.float32)
val = tf.transpose(val, [1, 0, 2])
last = tf.gather(val, int(val.get_shape()[0]) - 1)
weight = tf.Variable(tf.truncated_normal( [num_hidden, int(target.get_shape()[1])] ))

bias = tf.Variable(tf.constant(0.1, shape=[target.get_shape()[1]]))

prediction = tf.nn.relu(tf.matmul(last, weight) + bias)

#cross_entropy = -tf.reduce_sum(target * tf.log(tf.clip_by_value(prediction,1e-10,1.0)))
cost = tf.reduce_sum((prediction-target)**2)

optimizer = tf.train.AdamOptimizer()
minimize = optimizer.minimize(cost)

mistakes = tf.not_equal(tf.argmax(target, 1), tf.argmax(prediction, 1))
error = tf.reduce_mean(tf.cast(mistakes, tf.float32))
prediction = tf.nn.softmax(tf.matmul(last, weight) + bias)
init_op = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init_op)
batch_size = 2
no_of_batches = int(len(train_input) / batch_size)
epoch = 100
for i in range(epoch):
    ptr = 0
    for j in range(no_of_batches):
        inp, out = train_input[ptr:ptr + batch_size], train_output[ptr:ptr + batch_size]
        ptr += batch_size
        sess.run(minimize, {data: inp, target: out})
    print
    "Epoch ", str(i)

incorrect = sess.run(error, {data: test_input, target: test_output})
print(sess.run(bias))
#print(sess.run(prediction,{data:test_input}))
#print(incorrect)

sess.close()
